# %% [markdown]
# # snnTorch Test: Making $\alpha$ and $\beta$ learnable parameters
# ### By Jason K. Eshraghian

# %% [markdown]
# ## Gradient-based Learning in Spiking Neural Networks

# %%
# Install the test PyPi Distribution of snntorch
# !pip install -i https://test.pypi.org/simple/ snntorch
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# Collecting snntorch
#   Downloading https://test-files.pythonhosted.org/packages/0a/4b/1fadcfc6be25d336d0e2a82c0e7bcebaeb029728a98594fe95ef2202bb0b/snntorch-0.0.7-py3-none-any.whl
# Installing collected packages: snntorch
# Successfully installed snntorch-0.0.7

# %% [markdown]
# ## 1. Setting up the Static MNIST Dataset
# ### 1.1. Import packages and setup environment

# %%
import snntorch as snn
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import numpy as np
import itertools
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.2 Define network and SNN parameters
# We will use a 784-1000-10 FCN architecture for a sequence of 25 time steps.
#
# * `alpha` is the decay rate of the synaptic current of a neuron
# * `beta` is the decay rate of the membrane potential of a neuron

# %%
# Network Architecture
num_inputs = 28*28
num_hidden = 1000
num_outputs = 10

# Training Parameters
batch_size=128
data_path='/data/mnist'

# Temporal Dynamics
num_steps = 25
time_step = 1e-3
tau_mem = 3e-3
tau_syn = 2.2e-3

# these will be overridden
alpha = float(np.exp(-time_step/tau_syn))
beta = float(np.exp(-time_step/tau_mem))

dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %% [markdown]
# ### 1.3 Download MNIST Dataset

# %%
# Define a transform
transform = transforms.Compose([
            transforms.Resize((28, 28)),
            transforms.Grayscale(),
            transforms.ToTensor(),
            transforms.Normalize((0,), (1,))])

mnist_train = datasets.MNIST(data_path, train=True, download=True, transform=transform)
mnist_test = datasets.MNIST(data_path, train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /data/mnist/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /data/mnist/MNIST/raw/train-images-idx3-ubyte.gz to /data/mnist/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /data/mnist/MNIST/raw/train-labels-idx1-ubyte.gz to /data/mnist/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /data/mnist/MNIST/raw/t10k-images-idx3-ubyte.gz to /data/mnist/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /data/mnist/MNIST/raw/t10k-labels-idx1-ubyte.gz to /data/mnist/MNIST/raw
# Processing...
# Done!
# /usr/local/lib/python3.6/dist-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %% [markdown]
# ### 1.4 Create DataLoaders

# %%
train_loader = DataLoader(mnist_train, batch_size=batch_size, shuffle=True, drop_last=True)
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=True)

# %% [markdown]
# ## 2. Define Network
#
# Override snn.SRM0:
# * np.log(alpha) is now torch.log(alpha)
# * update tau_srm every time alpha and beta are changed by placing it in `forward`

# %%
class SRM0(snn.LIF):

    def __init__(self, alpha, beta, threshold=1.0, spike_grad=None):
        super(SRM0, self).__init__(alpha, beta, threshold, spike_grad)

        self.alpha = alpha
        self.beta = beta
        self.threshold = threshold

    def forward(self, input_, syn_pre, syn_post, mem):

        self.tau_srm = torch.log(self.alpha) / (torch.log(self.beta) - torch.log(self.alpha)) + 1
        spk, reset = self.fire(mem)
        syn_pre = (self.alpha*syn_pre + input_) * (1 - reset)
        syn_post = (self.beta * syn_post - input_) * (1 - reset)
        mem = self.tau_srm * (syn_pre + syn_post)*(1-reset) + (mem*reset - reset * self.threshold)

        return spk, syn_pre, syn_post, mem

# %%
class Stein(snn.LIF):

    def __init__(self, alpha, beta, threshold=1.0, num_inputs=False, spike_grad=None, batch_size=False, hidden_init=False):
        super(Stein, self).__init__(alpha, beta, threshold, spike_grad)

        self.alpha = alpha
        self.beta = beta
        self.threshold = threshold
        self.num_inputs = num_inputs
        self.batch_size = batch_size
        self.hidden_init = hidden_init

    def forward(self, input_, syn, mem):
        if not self.hidden_init:
            spk, reset = self.fire(mem)
            syn = self.alpha * syn + input_
            mem = self.beta * mem + syn - reset

            return spk, syn, mem

        # intended for truncated-BPTT where instance variables are hidden states
        if self.hidden_init:
            self.spk, self.reset = self.fire(self.mem)
            self.syn = self.alpha * self.syn + input_
            self.mem = self.beta * self.mem + self.syn - self.reset

            return self.spk, self.syn, self.mem

# %% [markdown]
# Note: alpha and beta are a single parameter each, therefore 1x1

# %%
# Define Network
class Net(nn.Module):
    def __init__(self):
        super().__init__()

    # initialize layers
        self.alpha = nn.Linear(1, 1, bias=False)
        self.beta = nn.Linear(1, 1, bias=False)
        self.fc1 = nn.Linear(num_inputs, num_hidden)
        # self.lif1 = SRM0(alpha=self.alpha.weight, beta=self.beta.weight, threshold=0.3) # NOTE: lowering threshold induces more spiking, coz SRM0 struggles with spiking.
        self.lif1 = Stein(alpha=self.alpha.weight, beta=self.beta.weight)
        self.fc2 = nn.Linear(num_hidden, num_outputs)
        # self.lif2 = SRM0(alpha=self.alpha.weight, beta=self.beta.weight, threshold=0.3)
        self.lif2 = Stein(alpha=self.alpha.weight, beta=self.beta.weight)

    # ====== UNCOMMENT FOR SRM0 ======= #

    # def forward(self, x):
    #     spk1, pre_syn1, post_syn1, mem1 = self.lif1.init_srm0(batch_size, num_hidden)
    #     spk2, pre_syn2, post_syn2, mem2 = self.lif2.init_srm0(batch_size, num_outputs)

    #     spk2_rec = []
    #     mem2_rec = []

    #     for step in range(num_steps):
    #         cur1 = self.fc1(x)
    #         spk1, pre_syn1, post_syn1, mem1 = self.lif1(cur1, pre_syn1, post_syn1, mem1)
    #         cur2 = self.fc2(spk1)
    #         spk2, pre_syn2, post_syn2, mem2 = self.lif2(cur2, pre_syn2, post_syn2, mem2)

    #         spk2_rec.append(spk2)
    #         mem2_rec.append(mem2)

    #     return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)


    # ======== STEIN ======= # 
    def forward(self, x):
        spk1, syn1, mem1 = self.lif1.init_stein(batch_size, num_hidden)
        spk2, syn2, mem2 = self.lif2.init_stein(batch_size, num_outputs)

        spk2_rec = []
        mem2_rec = []

        for step in range(num_steps):
            cur1 = self.fc1(x)
            spk1, syn1, mem1 = self.lif1(cur1, syn1, mem1)
            cur2 = self.fc2(spk1)
            spk2, syn2, mem2 = self.lif2(cur2, syn2, mem2)

            spk2_rec.append(spk2)
            mem2_rec.append(mem2)

        return torch.stack(spk2_rec, dim=0), torch.stack(mem2_rec, dim=0)

net = Net().to(device)

# %% [markdown]
# However, we need to check that alpha > beta AND alpha & beta > 0.
# So re-run the above till the following works.

# %%
print(net.alpha.weight)
print(net.beta.weight)
# Out:
# Parameter containing:
# tensor([[0.9543]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[0.8404]], device='cuda:0', requires_grad=True)

# %% [markdown]
# ## 3. Training

# %%
def print_batch_accuracy(data, targets, train=False):
    output, _ = net(data.view(batch_size, -1))
    _, idx = output.sum(dim=0).max(1)
    acc = np.mean((targets == idx).detach().cpu().numpy())

    if train:
        print(f"Train Set Accuracy: {acc}")
    else:
        print(f"Test Set Accuracy: {acc}")

def train_printer():
    print(net.alpha.weight)
    print(net.beta.weight)
    print(f"Epoch {epoch}, Minibatch {minibatch_counter}")
    print(f"Train Set Loss: {loss_hist[counter]}")
    print(f"Test Set Loss: {test_loss_hist[counter]}")
    print_batch_accuracy(data_it, targets_it, train=True)
    print_batch_accuracy(testdata_it, testtargets_it, train=False)
    print("\n")

# %% [markdown]
# ### 3.1 Training Loop

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=2e-4, betas=(0.9, 0.999))
log_softmax_fn = nn.LogSoftmax(dim=-1)
loss_fn = nn.NLLLoss()

loss_hist = []
test_loss_hist = []
counter = 0

# Outer training loop
for epoch in range(5):
    minibatch_counter = 0
    train_batch = iter(train_loader)

    # Minibatch training loop
    for data_it, targets_it in train_batch:
        data_it = data_it.to(device)
        targets_it = targets_it.to(device)

        output, mem_rec = net(data_it.view(batch_size, -1))
        log_p_y = log_softmax_fn(mem_rec)
        loss_val = torch.zeros((1), dtype=dtype, device=device)

        # Sum loss over time steps: BPTT
        for step in range(num_steps):
          loss_val += loss_fn(log_p_y[step], targets_it)

        # Gradient calculation
        optimizer.zero_grad()
        loss_val.backward(retain_graph=True)

        # Weight Update
        nn.utils.clip_grad_norm_(net.parameters(), 1) # gradient clipping
        optimizer.step()

        # Store loss history for future plotting
        loss_hist.append(loss_val.item())

        # Test set
        test_data = itertools.cycle(test_loader)
        testdata_it, testtargets_it = next(test_data)
        testdata_it = testdata_it.to(device)
        testtargets_it = testtargets_it.to(device)

        # Test set forward pass
        test_output, test_mem_rec = net(testdata_it.view(batch_size, -1))

        # Test set loss
        log_p_ytest = log_softmax_fn(test_mem_rec)
        log_p_ytest = log_p_ytest.sum(dim=0)
        loss_val_test = loss_fn(log_p_ytest, testtargets_it)
        test_loss_hist.append(loss_val_test.item())

        # Print test/train loss/accuracy
        if counter % 50 == 0:
            train_printer()
        minibatch_counter += 1
        counter += 1

loss_hist_true_grad = loss_hist
test_loss_hist_true_grad = test_loss_hist
# Out:
# Parameter containing:
# tensor([[1.0570]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1020]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 0
# Train Set Loss: 5.809924125671387
# Test Set Loss: 31.504987716674805
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.0631]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1087]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 50
# Train Set Loss: 7.581693172454834
# Test Set Loss: 96.35897827148438
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.0688]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1149]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 100
# Train Set Loss: 90.54174041748047
# Test Set Loss: 137.88638305664062
# Train Set Accuracy: 0.9609375
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.0743]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1210]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 150
# Train Set Loss: 25.766407012939453
# Test Set Loss: 46.26662063598633
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.0790]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1265]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 200
# Train Set Loss: 13.962873458862305
# Test Set Loss: 140.7577362060547
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9296875
#
#
# Parameter containing:
# tensor([[1.0842]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1323]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 250
# Train Set Loss: 9.800827026367188
# Test Set Loss: 80.27383422851562
# Train Set Accuracy: 0.96875
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.0886]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1372]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 300
# Train Set Loss: 27.599700927734375
# Test Set Loss: 41.815670013427734
# Train Set Accuracy: 0.9609375
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.0919]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1413]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 350
# Train Set Loss: 23.93905258178711
# Test Set Loss: 87.41280364990234
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.0968]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1469]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 400
# Train Set Loss: 99.47831726074219
# Test Set Loss: 66.67290496826172
# Train Set Accuracy: 0.9296875
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.1002]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1510]], device='cuda:0', requires_grad=True)
# Epoch 0, Minibatch 450
# Train Set Loss: 153.21051025390625
# Test Set Loss: 19.899412155151367
# Train Set Accuracy: 0.953125
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.1052]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1566]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 32
# Train Set Loss: 5.3765387535095215
# Test Set Loss: 420.28460693359375
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.921875
#
#
# Parameter containing:
# tensor([[1.1095]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1616]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 82
# Train Set Loss: 23.015159606933594
# Test Set Loss: 201.7172393798828
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.1143]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1670]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 132
# Train Set Loss: 146.87020874023438
# Test Set Loss: 233.2279510498047
# Train Set Accuracy: 0.953125
# Test Set Accuracy: 0.9140625
#
#
# Parameter containing:
# tensor([[1.1191]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1723]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 182
# Train Set Loss: 28.991060256958008
# Test Set Loss: 96.2659683227539
# Train Set Accuracy: 0.9609375
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.1248]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1786]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 232
# Train Set Loss: 28.353858947753906
# Test Set Loss: 5.6284637451171875
# Train Set Accuracy: 0.9453125
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.1275]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1821]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 282
# Train Set Loss: 5.2297821044921875
# Test Set Loss: 164.69512939453125
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.1303]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1856]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 332
# Train Set Loss: 14.067598342895508
# Test Set Loss: 202.66226196289062
# Train Set Accuracy: 0.96875
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.1344]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1905]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 382
# Train Set Loss: 5.238802433013916
# Test Set Loss: 404.9511413574219
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.1382]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1948]], device='cuda:0', requires_grad=True)
# Epoch 1, Minibatch 432
# Train Set Loss: 10.451321601867676
# Test Set Loss: 348.3030700683594
# Train Set Accuracy: 1.0
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.1404]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.1976]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 14
# Train Set Loss: 67.89578247070312
# Test Set Loss: 58.92698669433594
# Train Set Accuracy: 0.96875
# Test Set Accuracy: 0.984375
#
#
# Parameter containing:
# tensor([[1.1471]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2047]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 64
# Train Set Loss: 61.927249908447266
# Test Set Loss: 574.5935668945312
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.1543]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2126]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 114
# Train Set Loss: 10.542808532714844
# Test Set Loss: 598.808349609375
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.1604]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2191]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 164
# Train Set Loss: 48.62456512451172
# Test Set Loss: 377.1979064941406
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.1663]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2257]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 214
# Train Set Loss: 22.354061126708984
# Test Set Loss: 144.72369384765625
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.1720]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2321]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 264
# Train Set Loss: 5.000614643096924
# Test Set Loss: 226.23834228515625
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.1780]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2386]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 314
# Train Set Loss: 121.94904327392578
# Test Set Loss: 243.4937744140625
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.1821]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2434]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 364
# Train Set Loss: 475.30291748046875
# Test Set Loss: 971.0256958007812
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.1863]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2483]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 414
# Train Set Loss: 4.964321613311768
# Test Set Loss: 317.6903991699219
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.1902]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2528]], device='cuda:0', requires_grad=True)
# Epoch 2, Minibatch 464
# Train Set Loss: 13.966548919677734
# Test Set Loss: 586.4052124023438
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.1920]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2550]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 46
# Train Set Loss: 271.7633056640625
# Test Set Loss: 362.1779479980469
# Train Set Accuracy: 0.953125
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.1956]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2590]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 96
# Train Set Loss: 32.042808532714844
# Test Set Loss: 618.6083984375
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.2019]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2658]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 146
# Train Set Loss: 149.59201049804688
# Test Set Loss: 647.402587890625
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.2083]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2729]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 196
# Train Set Loss: 165.28919982910156
# Test Set Loss: 344.6748352050781
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.2152]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2802]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 246
# Train Set Loss: 450.81036376953125
# Test Set Loss: 1100.658447265625
# Train Set Accuracy: 0.9296875
# Test Set Accuracy: 0.9375
#
#
# Parameter containing:
# tensor([[1.2197]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2852]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 296
# Train Set Loss: 4.668883800506592
# Test Set Loss: 1705.2900390625
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.2257]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2917]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 346
# Train Set Loss: 454.0509033203125
# Test Set Loss: 1141.274169921875
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.2307]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.2972]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 396
# Train Set Loss: 260.3772888183594
# Test Set Loss: 960.3399047851562
# Train Set Accuracy: 0.96875
# Test Set Accuracy: 0.921875
#
#
# Parameter containing:
# tensor([[1.2346]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3017]], device='cuda:0', requires_grad=True)
# Epoch 3, Minibatch 446
# Train Set Loss: 662.6257934570312
# Test Set Loss: 1604.031494140625
# Train Set Accuracy: 0.96875
# Test Set Accuracy: 0.9609375
#
#
# Parameter containing:
# tensor([[1.2381]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3058]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 28
# Train Set Loss: 46.696327209472656
# Test Set Loss: 1949.016357421875
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.90625
#
#
# Parameter containing:
# tensor([[1.2438]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3117]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 78
# Train Set Loss: 538.478759765625
# Test Set Loss: 1811.764892578125
# Train Set Accuracy: 0.9453125
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.2484]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3169]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 128
# Train Set Loss: 484.9432373046875
# Test Set Loss: 720.3907470703125
# Train Set Accuracy: 0.9296875
# Test Set Accuracy: 0.9765625
#
#
# Parameter containing:
# tensor([[1.2539]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3229]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 178
# Train Set Loss: 4.605682373046875
# Test Set Loss: 3078.066162109375
# Train Set Accuracy: 0.9921875
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.2589]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3282]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 228
# Train Set Loss: 274.39288330078125
# Test Set Loss: 1527.7537841796875
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.9140625
#
#
# Parameter containing:
# tensor([[1.2644]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3342]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 278
# Train Set Loss: 1440.65234375
# Test Set Loss: 1205.7305908203125
# Train Set Accuracy: 0.9375
# Test Set Accuracy: 0.9453125
#
#
# Parameter containing:
# tensor([[1.2707]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3411]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 328
# Train Set Loss: 988.84716796875
# Test Set Loss: 1251.6119384765625
# Train Set Accuracy: 0.9765625
# Test Set Accuracy: 0.953125
#
#
# Parameter containing:
# tensor([[1.2758]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3467]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 378
# Train Set Loss: 281.17120361328125
# Test Set Loss: 2623.606201171875
# Train Set Accuracy: 0.984375
# Test Set Accuracy: 0.96875
#
#
# Parameter containing:
# tensor([[1.2817]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[1.3531]], device='cuda:0', requires_grad=True)
# Epoch 4, Minibatch 428
# Train Set Loss: 100.86127471923828
# Test Set Loss: 2649.255615234375
# Train Set Accuracy: 0.9609375
# Test Set Accuracy: 0.9140625

# %% [markdown]
# ## 4. Results
# Observations for **SRM**
# * alpha wants to go to 1
# * beta wants to go to 0
# * once beta hits 0, losses were all `nan`
# * Using SRM0, acc went up to 60% then tapered off btwn 35-40%
#
# Observations for **Stein**
# * alpha and beta started at about 95 & 84
# * appeared to initially decrease
# * then hit 85 & 80
# * then went back up to 90 & 85
# * then 90 stayed constant, while 85 --> 89
# * then 91 & 90 & gently increased together from there v slightly
# * THEN BETA OVERTOOK ALPHA 0.94 & 0.95, but I guess thats fine for Stein
# * then 0.98 & 1.01 happened...
# * then both exceeded 1: loss jumped up a bit, but accuracy was still reasonable
# * 1.02 & 1.06. train set loss went to acceptable values (5-11, sometimes it'd jump), while test loss jumped to 20 <--> 84
# *By 1.23 & 1.29, the loss fluctuated btwn train: 10 & 600; train: 400-3000, but with good accuracy
# * accuracy hits 95-99%
#
# ### 4.1 Plot Training/Test Loss

# %%
# Plot Loss
fig = plt.figure(facecolor="w", figsize=(10, 5))
plt.plot(loss_hist)
plt.plot(test_loss_hist)
plt.legend(["Test Loss", "Train Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ### 4.2 Test Set Accuracy
# This function just iterates over all minibatches to obtain a measure of accuracy over the full 10,000 samples in the test set.

# %%
total = 0
correct = 0
test_loader = DataLoader(mnist_test, batch_size=batch_size, shuffle=True, drop_last=False)

with torch.no_grad():
  net.eval()
  for data in test_loader:
    images, labels = data
    images = images.to(device)
    labels = labels.to(device)

    # If current batch matches batch_size, just do the usual thing
    if images.size()[0] == batch_size:
      outputs, _ = net(images.view(batch_size, -1))

    # If current batch does not match batch_size (e.g., is the final minibatch),
    # modify batch_size in a temp variable and restore it at the end of the else block
    else:
      temp_bs = batch_size
      batch_size = images.size()[0]
      outputs, _ = net(images.view(images.size()[0], -1))
      batch_size = temp_bs

    _, predicted = outputs.sum(dim=0).max(1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

print(f"Total correctly classified test set images: {correct}/{total}")
print(f"Test Set Accuracy: {100 * correct / total}%")
